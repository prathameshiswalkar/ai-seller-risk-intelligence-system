# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import seaborn as sns
import datetime as datetime

import pandas as pd
import numpy as np
import re
import nltk
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from transformers import MarianMTModel, MarianTokenizer
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import numpy as np
from tqdm import tqdm
from unidecode import unidecode
from sklearn.preprocessing import MinMaxScaler
from langchain_openai import OpenAI
import google.generativeai as genai
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.docstore.document import Document
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15292\3403144235.py:39: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
df = pd.read_csv(r"D:\customer-intelligence-engine\data\processed\late_delivery_dataset.csv")

# %%
df.head()
# Out:
#                            order_id                         seller_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202
# 1  00018f77f2f0320c557190d7a144bdd3  dd7ddc04e1b6c2c614352b383efe2d36
# 2  000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d
# 3  00024acbcdf0a6daa1e931b038114c75  9d7a1d34a5052409006425275ba1c2b4
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  df560393f3a51e74553ab94004ba5c87
#
#   order_purchase_timestamp order_delivered_customer_date  \
# 0           9/13/2017 8:59               9/20/2017 23:43
# 1          4/26/2017 10:53               5/12/2017 16:04
# 2          1/14/2018 14:33               1/22/2018 13:19
# 3           8/8/2018 10:00               8/14/2018 13:32
# 4           2/4/2017 13:57                3/1/2017 16:42
#
#   order_estimated_delivery_date  late_delivery delivery_days  \
# 0                9/29/2017 0:00              0             7
# 1                5/15/2017 0:00              0            16
# 2                 2/5/2018 0:00              0             8
# 3                8/20/2018 0:00              0             6
# 4                3/17/2017 0:00              0            25
#
#    estimated_delivery_days  order_month  order_weekday  total_payment_value  \
# 0                       16            9              4                72.19
# 1                       19            4              4               259.83
# 2                       22            1              1               216.87
# 3                       12            8              4                25.78
# 4                       41            2              7               218.04
#
#    avg_installments  total_price  total_freight  total_items
# 0               2.0        58.90          13.29            1
# 1               3.0       239.90          19.93            1
# 2               5.0       199.00          17.87            1
# 3               2.0        12.99          12.79            1
# 4               3.0       199.90          18.14            1

# %%
df.shape
# Out:
# (96477, 15)

# %%
df.dtypes
# Out:
# order_id                          object
# seller_id                         object
# order_purchase_timestamp          object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# late_delivery                      int64
# delivery_days                     object
# estimated_delivery_days            int64
# order_month                        int64
# order_weekday                      int64
# total_payment_value              float64
# avg_installments                 float64
# total_price                      float64
# total_freight                    float64
# total_items                        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'seller_id', 'order_purchase_timestamp',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'late_delivery', 'delivery_days', 'estimated_delivery_days',
#        'order_month', 'order_weekday', 'total_payment_value',
#        'avg_installments', 'total_price', 'total_freight', 'total_items'],
#       dtype='object')

# %%
df.late_delivery.value_counts(normalize = True)
# Out:
# late_delivery
# 0    0.918893
# 1    0.081107
# Name: proportion, dtype: float64

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df = df.drop(columns= ['order_id','delivery_days', 'order_purchase_timestamp', 'order_delivered_customer_date','order_estimated_delivery_date'])

# %%
df.head()
# Out:
#                           seller_id  late_delivery  estimated_delivery_days  \
# 0  48436dade18ac8b2bce089ec2a041202              0                       16
# 1  dd7ddc04e1b6c2c614352b383efe2d36              0                       19
# 2  5b51032eddd242adc84c38acab88f23d              0                       22
# 3  9d7a1d34a5052409006425275ba1c2b4              0                       12
# 4  df560393f3a51e74553ab94004ba5c87              0                       41
#
#    order_month  order_weekday  total_payment_value  avg_installments  \
# 0            9              4                72.19               2.0
# 1            4              4               259.83               3.0
# 2            1              1               216.87               5.0
# 3            8              4                25.78               2.0
# 4            2              7               218.04               3.0
#
#    total_price  total_freight  total_items
# 0        58.90          13.29            1
# 1       239.90          19.93            1
# 2       199.00          17.87            1
# 3        12.99          12.79            1
# 4       199.90          18.14            1

# %%
x = df.drop(['late_delivery'], axis = 1)
y = df['late_delivery']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state= 42, stratify=y)

# %%
train_df = x_train.copy()
train_df['late_orders'] = y_train

seller_delay = (
    train_df.groupby('seller_id')['late_orders'].mean().reset_index().rename(columns = {'late_orders' : 'seller_late_rate'})
)

# %%
# x_train = x_train.merge(seller_delay, on= 'seller_id', how = 'left')
# x_test = x_test.merge(seller_delay, on = 'seller_id', how = 'left')

seller_rate_dict = dict(
    zip(seller_delay['seller_id'], seller_delay['seller_late_rate'])
)
x_train['seller_late_rate'] = x_train['seller_id'].map(seller_rate_dict)
x_test['seller_late_rate'] = x_test['seller_id'].map(seller_rate_dict)

# %%
mean_rate = seller_delay['seller_late_rate'].mean()
x_train['seller_late_rate'] = x_train['seller_late_rate'].fillna(mean_rate)
x_test['seller_late_rate'] = x_test['seller_late_rate'].fillna(mean_rate)

# %%
x_train = x_train.drop(columns = ['seller_id'])
x_test = x_test.drop(columns =['seller_id'])

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
lr = LogisticRegression(max_iter= 1000, class_weight='balanced')
lr.fit(x_train_scaled, y_train)

y_pred = lr.predict(x_test_scaled)
y_prob = lr.predict_proba(x_test_scaled)[:,1]

# %%
print(classification_report(y_test,y_pred))
print("ROC AUC: ",roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80     17731
#            1       0.12      0.46      0.19      1565
#
#     accuracy                           0.68     19296
#    macro avg       0.53      0.58      0.49     19296
# weighted avg       0.87      0.68      0.75     19296
#
# ROC AUC:  0.620519575199336

# %%
rf = RandomForestClassifier(n_estimators= 200, max_depth= None, class_weight= 'balanced', random_state= 42)

# %%
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)
y_prob_rf = rf.predict_proba(x_test)[:,1]

print(classification_report(y_test,y_pred_rf))
print("ROC AUC: ",roc_auc_score(y_test, y_prob_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96     17731
#            1       0.35      0.06      0.10      1565
#
#     accuracy                           0.91     19296
#    macro avg       0.64      0.53      0.53     19296
# weighted avg       0.88      0.91      0.89     19296
#
# ROC AUC:  0.697172998753289

# %%
threshold = 0.20
y_pred_adj = (y_prob_rf >= threshold).astype(int)
print(classification_report(y_test, y_pred_adj))
print("ROC AUC: ",roc_auc_score(y_test, y_pred_adj))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92     17731
#            1       0.24      0.33      0.28      1565
#
#     accuracy                           0.86     19296
#    macro avg       0.59      0.62      0.60     19296
# weighted avg       0.88      0.86      0.87     19296
#
# ROC AUC:  0.6179234650311011

# %%
threshold = 0.15
y_pred_adj = (y_prob_rf >= threshold).astype(int)
print(classification_report(y_test, y_pred_adj))
print("ROC AUC: ",roc_auc_score(y_test, y_pred_adj))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90     17731
#            1       0.21      0.41      0.28      1565
#
#     accuracy                           0.82     19296
#    macro avg       0.58      0.64      0.59     19296
# weighted avg       0.88      0.82      0.85     19296
#
# ROC AUC:  0.6373296313400675

# %%
xgb = XGBClassifier(n_estimators= 300, 
                    max_depth = 6, 
                    learning_rate = 0.05, 
                    scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum(),
                    random_state = 42
                   )
xgb.fit(x_train, y_train)
y_prob_xgb = xgb.predict_proba(x_test)[:,1]
print("ROC AUC: ",roc_auc_score(y_test, y_prob_xgb))
# Out:
# ROC AUC:  0.7134602255251222

# %%
for threshold in [0.25, 0.20, 0.15]:
    y_pred_adj = (y_prob_xgb >= threshold).astype(int)
    print(f"\nThreshold : {threshold}")
    print(classification_report(y_test, y_pred_adj))
    print("ROC AUC: ",roc_auc_score(y_test, y_pred_adj))
# Out:
# Threshold : 0.25
#               precision    recall  f1-score   support
#
#            0       0.96      0.42      0.58     17731
#            1       0.11      0.83      0.20      1565
#
#     accuracy                           0.45     19296
#    macro avg       0.54      0.62      0.39     19296
# weighted avg       0.90      0.45      0.55     19296
#
# ROC AUC:  0.6228539823846
#
# Threshold : 0.2
#               precision    recall  f1-score   support
#
#            0       0.96      0.33      0.50     17731
#            1       0.10      0.86      0.18      1565
#
#     accuracy                           0.38     19296
#    macro avg       0.53      0.60      0.34     19296
# weighted avg       0.89      0.38      0.47     19296
#
# ROC AUC:  0.595458361314807
#
# Threshold : 0.15
#               precision    recall  f1-score   support
#
#            0       0.96      0.26      0.40     17731
#            1       0.10      0.89      0.17      1565
#
#     accuracy                           0.31     19296
#    macro avg       0.53      0.57      0.29     19296
# weighted avg       0.89      0.31      0.39     19296
#
# ROC AUC:  0.5708358657055035

# %%
# optimal threshold
from sklearn.metrics import precision_recall_curve
precision, recall, thresholds = precision_recall_curve(y_test, y_prob_xgb)
f1_scores = 2 *(precision * recall) / (precision + recall)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]

print("Best Threshold: ", best_threshold)
print("Best F1: ",f1_scores[best_idx])
# Out:
# Best Threshold:  0.6752754
# Best F1:  0.2984065668759054

# %%
import pandas as pd

feat_imp = pd.Series(
    xgb.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

print(feat_imp.head(10))
# Out:
# seller_late_rate           0.356529
# order_month                0.185277
# estimated_delivery_days    0.115840
# total_items                0.089483
# total_freight              0.088214
# total_payment_value        0.045621
# total_price                0.044592
# avg_installments           0.038602
# order_weekday              0.035842
# dtype: float32

# %%
y_pred_best = (y_prob_xgb > best_threshold).astype(int)
print(classification_report(y_test, y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92     17731
#            1       0.24      0.39      0.30      1565
#
#     accuracy                           0.85     19296
#    macro avg       0.59      0.64      0.61     19296
# weighted avg       0.89      0.85      0.87     19296

# %%
train_df[train_df['late_orders'] == 1]
# Out:
#                               seller_id  estimated_delivery_days  order_month  \
# 33337  cfe94489ddd337d1e29e12f2a7205d10                       18            5
# 15234  37515688008a7a40ac93e3b2e4ab203f                       24           11
# 90904  c37b2059d4f90d4feead554e5246565e                       27           12
# 29626  f7ba60f8c3f99e7ee4042fdef03b70c4                        5            8
# 4696   6560211a19b47992c3666cc44a7e94c0                       16           12
# ...                                 ...                      ...          ...
# 64399  6973a06f484aacf400ece213dbf3d946                       29            2
# 85537  3d871de0142ce09b7081e2b9d1733cb1                       24            3
# 66399  8581055ce74af1daba164fdbd55a40de                       17            3
# 24150  688756f717c462a206ad854c5027a64a                       22            5
# 89962  f46490624488d3ff7ce78613913a7711                        6            8
#
#        order_weekday  total_payment_value  avg_installments  total_price  \
# 33337              5               458.28               1.0       198.00
# 15234              7               158.40               1.0        49.00
# 90904              3              1851.75               1.0       299.50
# 29626              5                23.39               1.0        16.00
# 4696               2                62.78               3.0        55.00
# ...              ...                  ...               ...          ...
# 64399              4               100.23               1.0        84.89
# 85537              7                89.36               1.0        69.90
# 66399              3               110.82               1.0        92.10
# 24150              4               432.36               2.0       170.00
# 89962              5                31.43               1.0        19.00
#
#        total_freight  total_items  late_orders
# 33337          31.14            2            1
# 15234          30.20            2            1
# 90904          70.85            5            1
# 29626           7.39            1            1
# 4696            7.78            1            1
# ...              ...          ...          ...
# 64399          15.34            1            1
# 85537          19.46            1            1
# 66399          18.72            1            1
# 24150          46.18            2            1
# 89962          12.43            1            1
#
# [6260 rows x 10 columns]

# %%
seller_delay
# Out:
#                              seller_id  seller_late_rate
# 0     0015a82c2db000af6aaaf3ae2ecb0532          0.000000
# 1     001cca7ae9ae17fb1caed9dfb1094831          0.068750
# 2     002100f778ceb8431b7a1020ff7ab48f          0.205128
# 3     003554e2dce176b5555353e4f3555ac8          0.000000
# 4     004c9cd9d87a3c30c522c48c4fc07416          0.103175
# ...                                ...               ...
# 2822  ffc470761de7d0232558ba5e786e57b7          0.000000
# 2823  ffdd9f82b9a447f6f8d4b91554cc7dd3          0.000000
# 2824  ffeee66ac5d5a62fe688b9d26f83f534          0.142857
# 2825  fffd5413c0700ac820c7069d66d98c89          0.175000
# 2826  ffff564a4f9085cd26170f4732393726          0.000000
#
# [2827 rows x 2 columns]

# %%
# Seller Health Index
seller_df = pd.read_csv(r"D:\customer-intelligence-engine\data\processed\seller_metrics.csv")
seller_df.replace('\\N', np.nan, inplace=True)

# %%
seller_df.head()
# Out:
#                           seller_id  total_orders  total_revenue  \
# 0  48436dade18ac8b2bce089ec2a041202           156       17508.62
# 1  dd7ddc04e1b6c2c614352b383efe2d36           155       16014.54
# 2  5b51032eddd242adc84c38acab88f23d            14        6183.26
# 3  9d7a1d34a5052409006425275ba1c2b4            16        2556.23
# 4  df560393f3a51e74553ab94004ba5c87            37        4159.29
#
#    avg_order_value  late_delivery_rate avg_review_score  total_product_value  \
# 0           112.23              0.0641             4.03             12366.21
# 1           103.32              0.1677             3.77              9836.67
# 2           441.66              0.0000             3.79              3280.00
# 3           159.76              0.0625             3.75              1054.82
# 4           112.41              0.0541             3.68              4228.78
#
#    total_freight_value
# 0              3020.81
# 1              3172.07
# 2               268.95
# 3               277.05
# 4               727.81

# %%
seller_df.isna().sum()[seller_df.isna().sum() > 0]
# Out:
# avg_review_score    5
# dtype: int64

# %%
numeric_cols = ['total_orders', 'total_revenue', 'avg_order_value',
       'late_delivery_rate', 'avg_review_score', 'total_product_value',
       'total_freight_value']

for col in numeric_cols:
    seller_df[col] = pd.to_numeric(seller_df[col], errors = 'coerce')

# %%
seller_df.columns
# Out:
# Index(['seller_id', 'total_orders', 'total_revenue', 'avg_order_value',
#        'late_delivery_rate', 'avg_review_score', 'total_product_value',
#        'total_freight_value'],
#       dtype='object')

# %%
seller_df['avg_review_score'] = seller_df['avg_review_score'].fillna(4.15)

# %%
# Normalize Metrics
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

seller_df[['norm_revenue']] = scaler.fit_transform(seller_df[['total_revenue']])
seller_df[['norm_orders']] = scaler.fit_transform(seller_df[['total_orders']])
seller_df[['norm_review']] = scaler.fit_transform(seller_df[['avg_review_score']])
seller_df['inv_late_rate'] = 1 - seller_df['late_delivery_rate']
seller_df[['norm_late']] = scaler.fit_transform(seller_df[['inv_late_rate']])

# %%
seller_df.head()
# Out:
#                           seller_id  total_orders  total_revenue  \
# 0  48436dade18ac8b2bce089ec2a041202           156       17508.62
# 1  dd7ddc04e1b6c2c614352b383efe2d36           155       16014.54
# 2  5b51032eddd242adc84c38acab88f23d            14        6183.26
# 3  9d7a1d34a5052409006425275ba1c2b4            16        2556.23
# 4  df560393f3a51e74553ab94004ba5c87            37        4159.29
#
#    avg_order_value  late_delivery_rate  avg_review_score  total_product_value  \
# 0           112.23              0.0641              4.03             12366.21
# 1           103.32              0.1677              3.77              9836.67
# 2           441.66              0.0000              3.79              3280.00
# 3           159.76              0.0625              3.75              1054.82
# 4           112.41              0.0541              3.68              4228.78
#
#    total_freight_value  norm_revenue  norm_orders  norm_review  inv_late_rate  \
# 0              3020.81      0.034240     0.073286       0.7575         0.9359
# 1              3172.07      0.031316     0.072813       0.6925         0.8323
# 2               268.95      0.012073     0.006147       0.6975         1.0000
# 3               277.05      0.004974     0.007092       0.6875         0.9375
# 4               727.81      0.008111     0.017021       0.6700         0.9459
#
#    norm_late
# 0     0.9359
# 1     0.8323
# 2     1.0000
# 3     0.9375
# 4     0.9459

# %%
# 40% delivery reliability
# 30% review score
# 20% revenue
# 10% volume
seller_df['seller_health_index'] = (
    0.4 * seller_df['norm_late'] + 
    0.3 * seller_df['norm_review'] + 
    0.2 * seller_df['norm_revenue'] + 
    0.1 * seller_df['norm_orders']
)

# %%
seller_df
# Out:
#                              seller_id  total_orders  total_revenue  \
# 0     48436dade18ac8b2bce089ec2a041202           156       17508.62
# 1     dd7ddc04e1b6c2c614352b383efe2d36           155       16014.54
# 2     5b51032eddd242adc84c38acab88f23d            14        6183.26
# 3     9d7a1d34a5052409006425275ba1c2b4            16        2556.23
# 4     df560393f3a51e74553ab94004ba5c87            37        4159.29
# ...                                ...           ...            ...
# 2965  d1aa1ec0839dcab73a6161130eb1f94a             1         136.04
# 2966  dbc51f5e45d654ecc16cb68e6817ecea             1         218.13
# 2967  3fefda3299e6dfaea3466ef346a3571a             1         225.21
# 2968  80ceebb4ee9b31afb6c6a916a574a1e2             1        6922.21
# 2969  3e35a8bb43569389d3cebef0ce820f69             2         169.36
#
#       avg_order_value  late_delivery_rate  avg_review_score  \
# 0              112.23              0.0641              4.03
# 1              103.32              0.1677              3.77
# 2              441.66              0.0000              3.79
# 3              159.76              0.0625              3.75
# 4              112.41              0.0541              3.68
# ...               ...                 ...               ...
# 2965           136.04              1.0000              4.00
# 2966           218.13              0.0000              4.00
# 2967           225.21              0.0000              4.00
# 2968          6922.21              1.0000              4.15
# 2969            84.68              0.0000              5.00
#
#       total_product_value  total_freight_value  norm_revenue  norm_orders  \
# 0                12366.21              3020.81      0.034240     0.073286
# 1                 9836.67              3172.07      0.031316     0.072813
# 2                 3280.00               268.95      0.012073     0.006147
# 3                 1054.82               277.05      0.004974     0.007092
# 4                 4228.78               727.81      0.008111     0.017021
# ...                   ...                  ...           ...          ...
# 2965               119.90                16.14      0.000236     0.000000
# 2966               199.99                18.14      0.000397     0.000000
# 2967               209.00                16.21      0.000411     0.000000
# 2968              6729.00               193.21      0.013519     0.000000
# 2969                55.80                28.88      0.000302     0.000473
#
#       norm_review  inv_late_rate  norm_late  seller_health_index
# 0          0.7575         0.9359     0.9359             0.615787
# 1          0.6925         0.8323     0.8323             0.554215
# 2          0.6975         1.0000     1.0000             0.612279
# 3          0.6875         0.9375     0.9375             0.582954
# 4          0.6700         0.9459     0.9459             0.582684
# ...           ...            ...        ...                  ...
# 2965       0.7500         0.0000     0.0000             0.225047
# 2966       0.7500         1.0000     1.0000             0.625079
# 2967       0.7500         1.0000     1.0000             0.625082
# 2968       0.7875         0.0000     0.0000             0.238954
# 2969       1.0000         1.0000     1.0000             0.700108
#
# [2970 rows x 14 columns]

# %%
# Rank Sellers
seller_df = seller_df.sort_values(by = 'seller_health_index', ascending= False)
seller_df[['seller_id','seller_health_index']].head(10)
# Out:
#                             seller_id  seller_health_index
# 21   7c67e1448b00f6e969d365cea6b010ab             0.811580
# 13   1f50f920176fa81dab994f9023523100             0.794002
# 288  da8622b14eb17ae2831f4ac5b9dab84a             0.789566
# 12   4a3ca9315b744ce9f8e9374361493884             0.786857
# 182  1025f0e2d44d7041d6cf58b6550e0bfa             0.770543
# 22   6560211a19b47992c3666cc44a7e94c0             0.764398
# 52   955fee9216a65b617aa5c0531780ce60             0.761190
# 10   cc419e0650a3c5ba77189a1882b7556a             0.751656
# 192  53243585a1d6dc2643021fd1853d8905             0.748685
# 37   7a67c85e85bb2ce8582c35f2203ad736             0.745211

# %%
seller_df[['seller_id','seller_health_index']].tail(10)
# Out:
#                              seller_id  seller_health_index
# 2440  154bdf805377afea75a3bd158e9eab10             0.000037
# 1130  da2782c804606d2a5d8e1760dbb3e7ec             0.000035
# 2623  ca5832c6960267b71041f74bb39e8b12             0.000032
# 2749  3da38366e7bd9baf6369071f782ecdf0             0.000028
# 2240  391bbd13b6452244774beff1824006ed             0.000026
# 2433  63704069d9bd3a75c1cf59babe56004a             0.000020
# 2912  c1d1ebb4745cc43cb6f05e9c8a705c9a             0.000020
# 2852  8629a7efec1aab257e58cda559f03ba7             0.000019
# 1980  df683dfda87bf71ac3fc63063fba369d             0.000016
# 2902  20d53aad4fe5ee93a64f8839609d3586             0.000005

# %%
seller_df[['seller_health_index' , 'late_delivery_rate']].corr()
# Out:
#                      seller_health_index  late_delivery_rate
# seller_health_index              1.00000            -0.85661
# late_delivery_rate              -0.85661             1.00000

# %%
# Seller Segmentation
features = seller_df[['late_delivery_rate',	'avg_review_score', 'total_revenue', 'total_orders']]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

kmeans = KMeans(n_clusters= 4, random_state= 42)
seller_df['seller_segment'] = kmeans.fit_predict(scaled_features)

# %%
seller_df.groupby('seller_segment')[['late_delivery_rate',	'avg_review_score', 'total_revenue', 'total_orders']].mean()
# Out:
#                 late_delivery_rate  avg_review_score  total_revenue  \
# seller_segment
# 0                         0.034944          4.549743    2721.632090
# 1                         0.795874          2.607963    1124.506296
# 2                         0.079282          4.040588  220177.067059
# 3                         0.101342          3.478670   11895.074390
#
#                 total_orders
# seller_segment
# 0                  15.975296
# 1                   3.175926
# 2                1321.764706
# 3                  68.588692

# %%
seller_df.groupby('seller_segment')['total_revenue'].sum()
# Out:
# seller_segment
# 0     5288131.15
# 1      121446.68
# 2     3743010.14
# 3    10729357.10
# Name: total_revenue, dtype: float64

# %%
# Revenue Share by Segment
seller_df.groupby('seller_segment')['total_revenue'].sum().sort_values(ascending= False)
# Out:
# seller_segment
# 3    10729357.10
# 0     5288131.15
# 2     3743010.14
# 1      121446.68
# Name: total_revenue, dtype: float64

# %%
segment_revenue = seller_df.groupby('seller_segment')['total_revenue'].sum()
segment_revenue_pct = round(segment_revenue / segment_revenue.sum(), 2) * 100
segment_revenue_pct
# Out:
# seller_segment
# 0    27.0
# 1     1.0
# 2    19.0
# 3    54.0
# Name: total_revenue, dtype: float64

# %%
seller_df['revenue_at_risk'] = (seller_df['total_revenue'] * seller_df['late_delivery_rate'])

# %%
seller_df.groupby('seller_segment')[['revenue_at_risk', 'total_revenue']].sum()
# Out:
#                 revenue_at_risk  total_revenue
# seller_segment
# 0                 249332.731491     5288131.15
# 1                  85507.002955      121446.68
# 2                 308341.686973     3743010.14
# 3                 980406.776309    10729357.10

# %%
seller_df['reputation_risk'] = (seller_df['late_delivery_rate'] * (5 -seller_df['avg_review_score']))

# %%
seller_df.head(5)
# Out:
#                             seller_id  total_orders  total_revenue  \
# 21   7c67e1448b00f6e969d365cea6b010ab          1454      510915.44
# 13   1f50f920176fa81dab994f9023523100          2011      291526.94
# 288  da8622b14eb17ae2831f4ac5b9dab84a          1656      276093.09
# 12   4a3ca9315b744ce9f8e9374361493884          2116      300724.29
# 182  1025f0e2d44d7041d6cf58b6550e0bfa          1468      310186.70
#
#      avg_order_value  late_delivery_rate  avg_review_score  \
# 21            351.39              0.0928              3.40
# 13            144.97              0.0985              3.99
# 288           166.72              0.0694              4.08
# 12            142.12              0.1059              3.82
# 182           211.30              0.0906              3.88
#
#      total_product_value  total_freight_value  norm_revenue  norm_orders  \
# 21             198334.27             54323.68      1.000000     0.686998
# 13             111594.61             37308.56      0.570584     0.950355
# 288            170885.17             26707.23      0.540375     0.782506
# 12             212145.07             36963.26      0.588587     1.000000
# 182            142882.55             34829.67      0.607108     0.693617
#
#      norm_review  inv_late_rate  norm_late  seller_health_index  \
# 21        0.6000         0.9072     0.9072             0.811580
# 13        0.7475         0.9015     0.9015             0.794002
# 288       0.7700         0.9306     0.9306             0.789566
# 12        0.7050         0.8941     0.8941             0.786857
# 182       0.7200         0.9094     0.9094             0.770543
#
#      seller_segment  revenue_at_risk  reputation_risk
# 21                2     47412.952832         0.148480
# 13                2     28715.403590         0.099485
# 288               2     19160.860446         0.063848
# 12                2     31846.702311         0.124962
# 182               2     28102.915020         0.101472

# %%
seller_df.groupby('seller_segment')['reputation_risk'].mean()
# Out:
# seller_segment
# 0    0.019110
# 1    1.972157
# 2    0.076850
# 3    0.136462
# Name: reputation_risk, dtype: float64

# %%
# summary
segment_summary = seller_df.groupby('seller_segment').agg({
    'total_revenue' : 'sum',
    'late_delivery_rate' : 'mean',
    'avg_review_score' : 'mean',
    'revenue_at_risk' : 'sum'
})
segment_summary
# Out:
#                 total_revenue  late_delivery_rate  avg_review_score  \
# seller_segment
# 0                  5288131.15            0.034944          4.549743
# 1                   121446.68            0.795874          2.607963
# 2                  3743010.14            0.079282          4.040588
# 3                 10729357.10            0.101342          3.478670
#
#                 revenue_at_risk
# seller_segment
# 0                 249332.731491
# 1                  85507.002955
# 2                 308341.686973
# 3                 980406.776309

# %%
sns.boxplot(
    x = 'seller_segment',
    y = 'late_delivery_rate',
    data = seller_df
)
plt.title('Late Delivery Rate by Seller Segment')
plt.show()

# %%
sns.scatterplot(
    x = 'total_revenue',
    y = 'late_delivery_rate',
    hue = 'seller_segment',
    data = seller_df
)
plt.xscale('log')
plt.title('Revenue vs Late Rate')
plt.show()

# %%
# clean text
df = pd.read_csv(r"D:\customer-intelligence-engine\data\processed\dl_dataset.csv")

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#   review_score                             review_comment_message
# 0            5              Recebi bem antes do prazo estipulado.
# 1            5  Parabéns lojas lannister adorei comprar pela I...
# 2            4  aparelho eficiente. no site a marca do aparelh...
# 3            4   Mas um pouco ,travando...pelo valor ta Boa.\r\\n
# 4            5  Vendedor confiável, produto ok e entrega antes...

# %%
df['review_score'] = pd.to_numeric(df['review_score'] , errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41045 entries, 0 to 41044
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   review_id               41039 non-null  object
#  1   order_id                40981 non-null  object
#  2   review_score            40976 non-null  float64
#  3   review_comment_message  40976 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# review_id                  6
# order_id                  64
# review_score              69
# review_comment_message    69
# dtype: int64

# %%
df = df.dropna()

# %%
df = df[df['review_score'] != 3]
df['sentiment'] = df['review_score'].apply(lambda x: 1 if x >= 4 else 0 )

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    
    text = str(text).lower()                 # lowercase
    text = unidecode(text)                   # remove accents (ótimo → otimo)
    text = re.sub(r"\d+", "", text)          # remove numbers
    text = re.sub(r"[^a-z\s]", "", text)     # remove special characters
    text = re.sub(r"\s+", " ", text).strip() # remove extra spaces
    
    return text

df["clean_review"] = df["review_comment_message"].apply(clean_text)

# remove empty reviews
df = df[df["clean_review"] != ""]

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#    review_score                             review_comment_message  sentiment  \
# 0           5.0              Recebi bem antes do prazo estipulado.          1
# 1           5.0  Parabéns lojas lannister adorei comprar pela I...          1
# 2           4.0  aparelho eficiente. no site a marca do aparelh...          1
# 3           4.0   Mas um pouco ,travando...pelo valor ta Boa.\r\\n          1
# 4           5.0  Vendedor confiável, produto ok e entrega antes...          1
#
#                                         clean_review
# 0               recebi bem antes do prazo estipulado
# 1  parabens lojas lannister adorei comprar pela i...
# 2  aparelho eficiente no site a marca do aparelho...
# 3             mas um pouco travandopelo valor ta boa
# 4  vendedor confiavel produto ok e entrega antes ...

# %%
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

model.eval()
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(105879, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
def batch_predict(texts, batch_size = 32):
    all_predictions = []

    for i in tqdm(range(0, len(texts), batch_size)):
        batch = texts[i : i + batch_size].tolist()

        inputs = tokenizer(
            batch,
            return_tensors = "pt",
            padding = True,
            truncation = True,
            max_length = 128
        )

        with torch.no_grad():
            outputs = model(**inputs)

        probs = torch.nn.functional.softmax(outputs.logits, dim=1)
        preds = torch.argmax(probs, dim = 1) + 1

        all_predictions.extend(preds.tolist())
        
    return all_predictions

# %%
df.loc[:, 'bert_rating'] = batch_predict(df['clean_review'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1164/1164 [1:07:34<00:00,  3.48s/it]

# %%
def convert_to_sentiment(rating):
    if rating <= 2:
        return 'negative'
    elif rating == 3:
        return 'neutral'
    else:
        return "positive"

df.loc[:, 'bert_sentiment'] = df['bert_rating'].apply(convert_to_sentiment)

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#    review_score                             review_comment_message  sentiment  \
# 0           5.0              Recebi bem antes do prazo estipulado.          1
# 1           5.0  Parabéns lojas lannister adorei comprar pela I...          1
# 2           4.0  aparelho eficiente. no site a marca do aparelh...          1
# 3           4.0   Mas um pouco ,travando...pelo valor ta Boa.\r\\n          1
# 4           5.0  Vendedor confiável, produto ok e entrega antes...          1
#
#                                         clean_review  bert_rating  \
# 0               recebi bem antes do prazo estipulado            3
# 1  parabens lojas lannister adorei comprar pela i...            5
# 2  aparelho eficiente no site a marca do aparelho...            3
# 3             mas um pouco travandopelo valor ta boa            3
# 4  vendedor confiavel produto ok e entrega antes ...            4
#
#   bert_sentiment
# 0        neutral
# 1       positive
# 2        neutral
# 3        neutral
# 4       positive

# %%
def actual_sentiment(score):
    if score <= 2:
        return "negative"
    elif score == 3:
        return "neutral"
    else: 
        return "positive"

df.loc[:, "actual_sentiment"] = df["review_score"].apply(actual_sentiment)

# %%
print(classification_report(df['actual_sentiment'] , df['bert_sentiment']))
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#               precision    recall  f1-score   support
#
#     negative       0.70      0.89      0.79     10877
#      neutral       0.00      0.00      0.00         0
#     positive       0.97      0.75      0.84     26367
#
#     accuracy                           0.79     37244
#    macro avg       0.56      0.55      0.54     37244
# weighted avg       0.89      0.79      0.83     37244
# C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
df[df['bert_sentiment'] != df['actual_sentiment']].head()
# Out:
#                            review_id                          order_id  \
# 0   e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 2   8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3   4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 8   0e0190b9db53b689b285d3f3916f8441  79832b7cb59ac6f887088ffd686e1d5e
# 13  c92cdd7dd544a01aa35137f901669cdf  37e7875cdce5a9e5b3a692971f370151
#
#     review_score                             review_comment_message  \
# 0            5.0              Recebi bem antes do prazo estipulado.
# 2            4.0  aparelho eficiente. no site a marca do aparelh...
# 3            4.0   Mas um pouco ,travando...pelo valor ta Boa.\r\\n
# 8            5.0              obrigado pela atençao amim dispensada
# 13           4.0  Recebi exatamente o que esperava. As demais en...
#
#     sentiment                                       clean_review  bert_rating  \
# 0           1               recebi bem antes do prazo estipulado            3
# 2           1  aparelho eficiente no site a marca do aparelho...            3
# 3           1             mas um pouco travandopelo valor ta boa            3
# 8           1              obrigado pela atencao amim dispensada            1
# 13          1  recebi exatamente o que esperava as demais enc...            3
#
#    bert_sentiment actual_sentiment
# 0         neutral         positive
# 2         neutral         positive
# 3         neutral         positive
# 8        negative         positive
# 13        neutral         positive

# %%
df['review_score'].value_counts()
# Out:
# review_score
# 5.0    20441
# 1.0     8735
# 4.0     5926
# 2.0     2142
# Name: count, dtype: int64

# %%
order_items = pd.read_csv(r"D:\customer-intelligence-engine\data\raw\olist_order_items_dataset.csv")

# %%
order_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
df = df.merge(
    order_items[['order_id', 'seller_id']],
    on = 'order_id',
    how = 'left'
)

# %%
seller_sentiment = df.groupby("seller_id").agg(
    total_reviews = ('bert_sentiment' , 'count' ),
    negative_reviews = ('bert_sentiment' , lambda x : (x == 'negative').sum() ),
    positive_reviews = ('bert_sentiment' , lambda x : (x == 'positive').sum() )
).reset_index()

seller_sentiment['negative_rate'] = (seller_sentiment['negative_reviews'] / seller_sentiment['total_reviews'])

# %%
seller_sentiment
# Out:
#                              seller_id  total_reviews  negative_reviews  \
# 0     0015a82c2db000af6aaaf3ae2ecb0532              1                 1
# 1     001cca7ae9ae17fb1caed9dfb1094831            108                36
# 2     001e6ad469a905060d959994f1b41e4f              1                 1
# 3     002100f778ceb8431b7a1020ff7ab48f             14                 6
# 4     004c9cd9d87a3c30c522c48c4fc07416             59                17
# ...                                ...            ...               ...
# 2508  ffcfefa19b08742c5d315f2791395ee5              1                 1
# 2509  ffdd9f82b9a447f6f8d4b91554cc7dd3             10                 3
# 2510  ffeee66ac5d5a62fe688b9d26f83f534              8                 2
# 2511  fffd5413c0700ac820c7069d66d98c89             26                13
# 2512  ffff564a4f9085cd26170f4732393726             11                 9
#
#       positive_reviews  negative_rate
# 0                    0       1.000000
# 1                   56       0.333333
# 2                    0       1.000000
# 3                    6       0.428571
# 4                   34       0.288136
# ...                ...            ...
# 2508                 0       1.000000
# 2509                 5       0.300000
# 2510                 6       0.250000
# 2511                 9       0.500000
# 2512                 2       0.818182
#
# [2513 rows x 5 columns]

# %%
df = df.merge(
    seller_sentiment[['seller_id','negative_rate']],
    on = 'seller_id',
    how = 'left'
)
df['negative_rate'] = df['negative_rate'].fillna(0)

# %%
scaler = MinMaxScaler()
df['inv_negative_rate'] = 1 - df['negative_rate']
df['norm_negative'] = scaler.fit_transform(df[['inv_negative_rate']])

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 1  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 2  8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 3  4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 4  3948b09f7c818e2d86c9a546758b2335  e51478e7e277a83743b6f9991dbfa3fb
#
#    review_score                             review_comment_message  sentiment  \
# 0           5.0              Recebi bem antes do prazo estipulado.          1
# 1           5.0  Parabéns lojas lannister adorei comprar pela I...          1
# 2           4.0  aparelho eficiente. no site a marca do aparelh...          1
# 3           4.0   Mas um pouco ,travando...pelo valor ta Boa.\r\\n          1
# 4           5.0  Vendedor confiável, produto ok e entrega antes...          1
#
#                                         clean_review  bert_rating  \
# 0               recebi bem antes do prazo estipulado            3
# 1  parabens lojas lannister adorei comprar pela i...            5
# 2  aparelho eficiente no site a marca do aparelho...            3
# 3             mas um pouco travandopelo valor ta boa            3
# 4  vendedor confiavel produto ok e entrega antes ...            4
#
#   bert_sentiment actual_sentiment                         seller_id  \
# 0        neutral         positive  a1043bafd471dff536d0c462352beb48
# 1       positive         positive  989becdce12ebc39863c2bceab6f3ca1
# 2        neutral         positive  05ff92fedb5be47920fea08e501238b9
# 3        neutral         positive  db4350fd57ae30082dec7acbaacc17f9
# 4       positive         positive  974cf2cb8f4b7add98709c30df02fe10
#
#    negative_rate  inv_negative_rate  norm_negative
# 0       0.320144           0.679856       0.679856
# 1       0.375000           0.625000       0.625000
# 2       0.210526           0.789474       0.789474
# 3       0.435484           0.564516       0.564516
# 4       0.214286           0.785714       0.785714

# %%
seller_sentiment = df.groupby("seller_id").agg(
    negative_rate=("negative_rate","mean")
).reset_index()

# %%
print(seller_df.columns)
# Out:
# Index(['seller_id', 'total_orders', 'total_revenue', 'avg_order_value',
#        'late_delivery_rate', 'avg_review_score', 'total_product_value',
#        'total_freight_value', 'norm_revenue', 'norm_orders', 'norm_review',
#        'inv_late_rate', 'norm_late', 'seller_health_index', 'seller_segment',
#        'revenue_at_risk', 'reputation_risk'],
#       dtype='object')

# %%
seller_df = seller_df.merge(
    seller_sentiment,
    on="seller_id",
    how="left",
    suffixes = ("","_new")
)

seller_df["negative_rate"] = seller_df["negative_rate"].fillna(0)
seller_df["inv_negative_rate"] = 1 - seller_df["negative_rate"]

scaler = MinMaxScaler()
seller_df["norm_negative"] = scaler.fit_transform(
    seller_df[["inv_negative_rate"]]
)

# %%
seller_df.columns
# Out:
# Index(['seller_id', 'total_orders', 'total_revenue', 'avg_order_value',
#        'late_delivery_rate', 'avg_review_score', 'total_product_value',
#        'total_freight_value', 'norm_revenue', 'norm_orders', 'norm_review',
#        'inv_late_rate', 'norm_late', 'seller_health_index', 'seller_segment',
#        'revenue_at_risk', 'reputation_risk', 'negative_rate',
#        'inv_negative_rate', 'norm_negative'],
#       dtype='object')

# %%
scaler = MinMaxScaler() 
seller_df['norm_negative'] = scaler.fit_transform(seller_df[['inv_negative_rate']])

# %%
seller_df["inv_negative_rate"] = 1 - seller_df["negative_rate"]

seller_df['seller_health_index_v2'] = (
    0.30 * seller_df['norm_revenue'] + 
    0.15 * seller_df['norm_orders'] + 
    0.20 * seller_df['norm_review'] + 
    0.15 * seller_df['norm_late'] + 
    0.20 * seller_df['norm_negative']
)

# %%
print(seller_df.columns)
print(df.columns)
# Out:
# Index(['seller_id', 'total_orders', 'total_revenue', 'avg_order_value',
#        'late_delivery_rate', 'avg_review_score', 'total_product_value',
#        'total_freight_value', 'norm_revenue', 'norm_orders', 'norm_review',
#        'inv_late_rate', 'norm_late', 'seller_health_index', 'seller_segment',
#        'revenue_at_risk', 'reputation_risk', 'negative_rate',
#        'inv_negative_rate', 'norm_negative', 'seller_health_index_v2'],
#       dtype='object')
# Index(['review_id', 'order_id', 'review_score', 'review_comment_message',
#        'sentiment', 'clean_review', 'bert_rating', 'bert_sentiment',
#        'actual_sentiment', 'seller_id', 'negative_rate', 'inv_negative_rate',
#        'norm_negative'],
#       dtype='object')

# %%
seller_df.sort_values("seller_health_index_v2").head(10)
# Out:
#                              seller_id  total_orders  total_revenue  \
# 2968  df683dfda87bf71ac3fc63063fba369d             1          55.95
# 2967  8629a7efec1aab257e58cda559f03ba7             1          64.11
# 2966  c1d1ebb4745cc43cb6f05e9c8a705c9a             1          65.14
# 2965  63704069d9bd3a75c1cf59babe56004a             1          66.69
# 2964  391bbd13b6452244774beff1824006ed             1          81.60
# 2963  3da38366e7bd9baf6369071f782ecdf0             1          86.43
# 2961  da2782c804606d2a5d8e1760dbb3e7ec             1         103.37
# 2955  19484c79cef6c062cb177aa4ef2fcc3c             1         212.06
# 2954  d1a5cc844736958c11b8efab9a2b4c87             1         254.01
# 2953  984c273121e743dd14767befe6cb17f5             1         280.91
#
#       avg_order_value  late_delivery_rate  avg_review_score  \
# 2968            55.95                 1.0               1.0
# 2967            64.11                 1.0               1.0
# 2966            65.14                 1.0               1.0
# 2965            66.69                 1.0               1.0
# 2964            81.60                 1.0               1.0
# 2963            86.43                 1.0               1.0
# 2961           103.37                 1.0               1.0
# 2955           212.06                 1.0               1.0
# 2954           254.01                 1.0               1.0
# 2953           280.91                 1.0               1.0
#
#       total_product_value  total_freight_value  norm_revenue  norm_orders  \
# 2968                39.90                16.05      0.000080          0.0
# 2967                45.22                18.89      0.000096          0.0
# 2966                12.50                19.21      0.000098          0.0
# 2965                59.30                 7.39      0.000101          0.0
# 2964                63.90                17.70      0.000130          0.0
# 2963                59.47                26.96      0.000139          0.0
# 2961                89.00                14.37      0.000173          0.0
# 2955               201.90                10.16      0.000385          0.0
# 2954               237.60                16.41      0.000467          0.0
# 2953               259.60                21.31      0.000520          0.0
#
#       ...  inv_late_rate  norm_late  seller_health_index  seller_segment  \
# 2968  ...            0.0        0.0             0.000016               1
# 2967  ...            0.0        0.0             0.000019               1
# 2966  ...            0.0        0.0             0.000020               1
# 2965  ...            0.0        0.0             0.000020               1
# 2964  ...            0.0        0.0             0.000026               1
# 2963  ...            0.0        0.0             0.000028               1
# 2961  ...            0.0        0.0             0.000035               1
# 2955  ...            0.0        0.0             0.000077               1
# 2954  ...            0.0        0.0             0.000093               1
# 2953  ...            0.0        0.0             0.000104               1
#
#       revenue_at_risk  reputation_risk  negative_rate  inv_negative_rate  \
# 2968            55.95              4.0            1.0                0.0
# 2967            64.11              4.0            1.0                0.0
# 2966            65.14              4.0            1.0                0.0
# 2965            66.69              4.0            1.0                0.0
# 2964            81.60              4.0            1.0                0.0
# 2963            86.43              4.0            1.0                0.0
# 2961           103.37              4.0            1.0                0.0
# 2955           212.06              4.0            1.0                0.0
# 2954           254.01              4.0            1.0                0.0
# 2953           280.91              4.0            1.0                0.0
#
#       norm_negative  seller_health_index_v2
# 2968            0.0                0.000024
# 2967            0.0                0.000029
# 2966            0.0                0.000029
# 2965            0.0                0.000030
# 2964            0.0                0.000039
# 2963            0.0                0.000042
# 2961            0.0                0.000052
# 2955            0.0                0.000116
# 2954            0.0                0.000140
# 2953            0.0                0.000156
#
# [10 rows x 21 columns]

# %%
seller_df['seller_health_index_v2'].min()
# Out:
# np.float64(2.391660743461805e-05)

# %%
seller_df['sentiment_weighted_risk'] = (
    seller_df['late_delivery_rate'] * 
    seller_df['negative_rate'] * 
    seller_df['total_revenue']
)

# %%
segment_risk = seller_df.groupby('seller_segment')['sentiment_weighted_risk'].sum()

# %%
seller_df.seller_segment.value_counts()
# Out:
# seller_segment
# 0    1943
# 3     902
# 1     108
# 2      17
# Name: count, dtype: int64

# %%
segment_risk
# Out:
# seller_segment
# 0     76350.069793
# 1     46305.434931
# 2    126447.664791
# 3    431349.039892
# Name: sentiment_weighted_risk, dtype: float64

# %%
risky_sellers = seller_df[
    seller_df['seller_segment'] == 3].sort_values('sentiment_weighted_risk', ascending = False).head(5)

# %%
risky_sellers[['seller_id','total_revenue','late_delivery_rate','negative_rate']]
# Out:
#                              seller_id  total_revenue  late_delivery_rate  \
# 2759  b37c4c02bda3161a7546a4e6d222d5b2      145319.04              0.0667
# 2533  88460e8ebdecbfecb5f9601833981930       58357.94              0.1873
# 2548  8e6d7754bc7e0f22c96d255ebda59eba       75793.23              0.1269
# 1025  7d13fca15225358621be4086e1eb0964      127843.43              0.1169
# 1020  25c5c91f63607446a97b143d2d535d31      161379.92              0.0582
#
#       negative_rate
# 2759       0.923077
# 2533       0.753846
# 2548       0.760870
# 1025       0.396226
# 1020       0.612613

# %%
seller = risky_sellers.iloc[0]

# %%
seller
# Out:
# seller_id                  b37c4c02bda3161a7546a4e6d222d5b2
# total_orders                                             15
# total_revenue                                     145319.04
# avg_order_value                                     9687.94
# late_delivery_rate                                   0.0667
# avg_review_score                                        1.4
# total_product_value                                 24075.0
# total_freight_value                                   412.6
# norm_revenue                                       0.284407
# norm_orders                                        0.006619
# norm_review                                             0.1
# inv_late_rate                                        0.9333
# norm_late                                            0.9333
# seller_health_index                                0.460863
# seller_segment                                            3
# revenue_at_risk                                 9692.779968
# reputation_risk                                     0.24012
# negative_rate                                      0.923077
# inv_negative_rate                                  0.076923
# norm_negative                                      0.076923
# seller_health_index_v2                             0.261695
# sentiment_weighted_risk                         8947.181509
# Name: 2759, dtype: object

# %%
genai.configure(api_key = "AIzaSyBavHNMnwDWQtpMBztOM_o20HR-HF8Z5L0")
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
prompt = f"""
You're a Senior E-commerce Business Consultant

Seller Metrics:
Revenue: {seller.total_revenue}
Late Delivery {seller.late_delivery_rate}
Negative Review Rate: {seller.negative_rate}


Explain:
1. Why this seller is risky
2. What operational issues may exists
3. A strategic improvement plan

Respond professionally in english
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# Subject: Assessment of Seller Performance and Strategic Improvement Plan
#
# Dear Seller,
#
# Thank you for providing your recent performance metrics for review. As a Senior E-commerce Business Consultant, my analysis reveals a critical situation that demands immediate and comprehensive attention. While your revenue indicates significant sales activity, the associated performance metrics signal severe underlying issues that place your business at extreme risk.
#
# ---
#
# ### 1. Why This Seller Is Risky
#
# Based on the provided metrics, this seller is facing an existential threat and is extremely risky for several reasons:
#
# *   **Catastrophic Negative Review Rate (92.31%):** This is the single most alarming metric. A negative review rate of over 92% indicates that nearly every customer is having a poor experience. This is not merely an area for improvement; it's a **fundamental failure** in product quality, service, or both.
#     *   **Immediate Impact:** This rate will lead to a rapid decline in sales as new customers are deterred by overwhelmingly negative feedback.
#     *   **Platform Penalties:** E-commerce platforms (Amazon, eBay, Etsy, Shopify, etc.) have strict performance thresholds. A negative review rate this high will almost certainly lead to account suspension or outright termination, severing your sales channels.
#     *   **Brand Reputation Damage:** The negative sentiment extends beyond the platform, damaging your brand's reputation and making future growth extremely difficult, even if you were to move to another platform.
#     *   **Poor Customer Lifetime Value (CLTV):** Unhappy customers do not make repeat purchases. This dramatically reduces the long-term value of your customer base.
#     *   **Increased Returns/Refunds:** High dissatisfaction often correlates with higher return rates, impacting profitability and increasing operational overhead.
#
# *   **Concerning Late Delivery Rate (6.67%):** While not as catastrophic as the review rate, a late delivery rate of 6.67% is well above industry best practices (which typically aim for under 2-3%). This directly contributes to customer dissatisfaction and is a significant factor in negative reviews.
#     *   **Customer Frustration:** Delays lead to unhappy customers, especially in today's expectation of fast shipping.
#     *   **Platform Compliance:** Many platforms penalize sellers for consistently late shipments, affecting search ranking and eligibility for programs like Prime.
#     *   **Operational Inefficiency:** This rate points to systemic issues within your fulfillment process.
#
# *   **Unsustainable Revenue:** While a revenue of $145,319.04 is a good starting point, it is **highly unsustainable** with these performance metrics. This revenue is likely built on a foundation of unhappy first-time buyers who will not return, and will actively deter others. Without a drastic change, this revenue will plummet very quickly.
#
# ---
#
# ### 2. What Operational Issues May Exist
#
# The severe negative review rate and concerning late delivery rate point to a multitude of deeply rooted operational issues. We can infer the following:
#
# **Primary Issues (Driven by Negative Reviews):**
#
# 1.  **Product Quality & Accuracy:**
#     *   **Defective or Low-Quality Products:** The most probable cause. Products may not meet customer expectations, break quickly, or are poorly manufactured.
#     *   **Inaccurate Product Descriptions/Imagery:** Products received do not match what was advertised, leading to disappointment and feeling misled.
#     *   **Wrong Items Shipped:** Errors in picking and packing, leading to customers receiving incorrect products.
# 2.  **Customer Service:**
#     *   **Non-existent or Poor Customer Support:** Customers may be unable to get help, receive slow responses, or encounter unhelpful/unempathetic staff when issues arise.
#     *   **Lack of Resolution:** Even when issues are reported, they may not be resolved to the customer's satisfaction.
# 3.  **Packaging & Handling:**
#     *   **Damaged Goods:** Items arriving damaged due to inadequate packaging or rough handling during transit.
# 4.  **Value Proposition:**
#     *   **Overpriced:** Customers may feel they did not receive value for money, even if the product itself isn't defective, leading to negative perceptions.
#
# **Secondary Issues (Driven by Late Delivery & Contributing to Negative Reviews):**
#
# 1.  **Inventory Management:**
#     *   **Stock-outs:** Selling products that are not in stock, leading to delays as you wait for replenishment.
#     *   **Inaccurate Inventory Counts:** Discrepancies between advertised stock and actual stock.
# 2.  **Order Fulfillment Process:**
#     *   **Inefficient Picking & Packing:** Slow or error-prone internal warehouse processes.
#     *   **Understaffing/Untrained Staff:** Insufficient personnel or poorly trained staff in the fulfillment department.
#     *   **Lack of Automation:** Manual processes that are prone to human error and slowness.
# 3.  **Shipping & Logistics:**
#     *   **Poor Carrier Selection:** Using unreliable shipping carriers or services that consistently miss delivery windows.
#     *   **Incorrect Shipping Labels/Information:** Errors leading to packages being misrouted or delayed.
#     *   **Lack of Proactive Communication:** Failing to inform customers about potential delays or providing incorrect tracking information.
#
# ---
#
# ### 3. A Strategic Improvement Plan
#
# This situation requires an immediate, aggressive, and multi-faceted strategic improvement plan focused on radical change, not incremental tweaks.
#
# **Phase 1: Immediate Crisis Management & Root Cause Analysis (Days 1-7)**
#
# 1.  **Pause New Customer Acquisition:** Immediately halt all paid advertising and new marketing efforts. Do not acquire more unhappy customers until core issues are addressed.
# 2.  **Deep Dive into Negative Reviews:**
#     *   **Categorize & Analyze:** Manually review every single negative comment. Categorize them (e.g., product quality, wrong item, late delivery, broken, poor customer service). Identify the top 3-5 most frequent complaints.
#     *   **Identify Specific SKUs:** Pinpoint if certain products (SKUs) are disproportionately responsible for the negative feedback.
# 3.  **Proactive Customer Outreach (if feasible):** For recent negative reviews, reach out to affected customers with genuine apologies and offers of resolution (refund, replacement, discount). The goal is to mitigate further damage and potentially convert some to neutral or even positive.
# 4.  **Operational Audit:** Conduct an immediate, end-to-end review of your entire operation:
#     *   Product sourcing/manufacturing quality control.
#     *   Inventory management processes.
#     *   Order processing (picking, packing, labeling).
#     *   Shipping carrier performance and alternatives.
#     *   Customer service workflows and training.
#
# **Phase 2: Product & Quality Remediation (Weeks 1-4)**
#
# 1.  **Product Portfolio Review:**
#     *   **Identify Problem Products:** Discontinue or remove from sale any products identified as high contributors to negative reviews until issues are resolved.
#     *   **Enhance Product Quality:** Work with suppliers to improve product quality. Implement rigorous pre-shipment quality checks (e.g., third-party inspections).
#     *   **Accurate Product Listings:** Revise all product descriptions, images, and specifications to be 100% accurate and realistic. Manage customer expectations effectively.
# 2.  **Packaging Improvements:** Invest in robust and appropriate packaging to ensure products arrive undamaged.
#
# **Phase 3: Fulfillment & Logistics Overhaul (Weeks 1-6)**
#
# 1.  **Streamline Order Fulfillment:**
#     *   **Process Optimization:** Re-design your picking, packing, and labeling processes for efficiency and accuracy.
#     *   **Inventory Accuracy:** Implement or improve an Inventory Management System (IMS). Conduct regular stock audits.
#     *   **Staff Training & Resources:** Ensure fulfillment staff are adequately trained, equipped, and sufficient in number.
# 2.  **Improve Shipping Performance:**
#     *   **Carrier Review:** Evaluate your current shipping carriers. Negotiate better service levels or explore more reliable alternatives.
#     *   **Service Level Agreements (SLAs):** Set clear internal SLAs for order processing and dispatch times.
#     *   **Proactive Communication:** Implement automated systems to communicate shipping updates and potential delays to customers.
#
# **Phase 4: Customer Service Excellence & Reputation Rebuilding (Ongoing)**
#
# 1.  **Comprehensive Customer Service Training:**
#     *   **Empowerment:** Train staff to resolve issues quickly and effectively, with clear guidelines for refunds, replacements, and concessions.
#     *   **Empathy & Communication:** Focus on active listening, clear communication, and de-escalation techniques.
#     *   **Product Knowledge:** Ensure CS staff have in-depth product knowledge.
# 2.  **Establish Clear Service Level Agreements (SLAs):** Define targets for response times (e.g., within 12-24 hours) and resolution times.
# 3.  **Feedback Loop Implementation:** Create a structured process for customer feedback (positive and negative) to be analyzed and fed directly back to product development, operations, and marketing teams.
# 4.  **Strategic Review Management:** Once the underlying operational and product issues are demonstrably improved, implement a strategy to encourage positive reviews from satisfied customers. This is only effective *after* the problems are fixed.
#
# **Phase 5: Monitoring & Continuous Improvement (Ongoing)**
#
# 1.  **Key Performance Indicator (KPI) Tracking:** Continuously monitor:
#     *   Negative Review Rate (target: <2-3%)
#     *   Late Delivery Rate (target: <2%)
#     *   Customer Satisfaction Scores (CSAT)
#     *   Return Rate
#     *   Platform Performance Metrics (seller health dashboard)
# 2.  **Regular Performance Reviews:** Conduct weekly/monthly reviews of these KPIs to identify trends, celebrate successes, and address new issues promptly.
# 3.  **Benchmarking:** Compare your metrics against industry averages and top-performing competitors.
#
# ---
#
# This is an extremely challenging situation, but with a disciplined and aggressive approach to identifying and rectifying the root causes, it is possible to turn the business around. The immediate focus must be on stopping the bleed from customer dissatisfaction and rebuilding trust.
#
# I am available to discuss this plan further and assist in its implementation.
#
# Sincerely,
#
# Your Senior E-commerce Business Consultant

# %%
# for m in genai.list_models():
#     print(m.name)

# %%
# Platform Averages
platform_avg = {
    "late_delivery_rate" : seller_df['late_delivery_rate'].mean(),
    "negative_rate" : seller_df['negative_rate'].mean(),
    "avg_review_score" : seller_df["avg_review_score"].mean()
}

# %%
# Comparative Flags
seller_df["late_vs_avg"] = (seller_df["late_delivery_rate"] - platform_avg['late_delivery_rate'])

# %%
seller_df["negative_vs_avg"] = (seller_df["negative_rate"] - platform_avg['negative_rate'])

# %%
seller_df
# Out:
#                              seller_id  total_orders  total_revenue  \
# 0     7c67e1448b00f6e969d365cea6b010ab          1454      510915.44
# 1     1f50f920176fa81dab994f9023523100          2011      291526.94
# 2     da8622b14eb17ae2831f4ac5b9dab84a          1656      276093.09
# 3     4a3ca9315b744ce9f8e9374361493884          2116      300724.29
# 4     1025f0e2d44d7041d6cf58b6550e0bfa          1468      310186.70
# ...                                ...           ...            ...
# 2965  63704069d9bd3a75c1cf59babe56004a             1          66.69
# 2966  c1d1ebb4745cc43cb6f05e9c8a705c9a             1          65.14
# 2967  8629a7efec1aab257e58cda559f03ba7             1          64.11
# 2968  df683dfda87bf71ac3fc63063fba369d             1          55.95
# 2969  20d53aad4fe5ee93a64f8839609d3586             1          26.98
#
#       avg_order_value  late_delivery_rate  avg_review_score  \
# 0              351.39              0.0928              3.40
# 1              144.97              0.0985              3.99
# 2              166.72              0.0694              4.08
# 3              142.12              0.1059              3.82
# 4              211.30              0.0906              3.88
# ...               ...                 ...               ...
# 2965            66.69              1.0000              1.00
# 2966            65.14              1.0000              1.00
# 2967            64.11              1.0000              1.00
# 2968            55.95              1.0000              1.00
# 2969            26.98              1.0000              1.00
#
#       total_product_value  total_freight_value  norm_revenue  norm_orders  \
# 0               198334.27             54323.68      1.000000     0.686998
# 1               111594.61             37308.56      0.570584     0.950355
# 2               170885.17             26707.23      0.540375     0.782506
# 3               212145.07             36963.26      0.588587     1.000000
# 4               142882.55             34829.67      0.607108     0.693617
# ...                   ...                  ...           ...          ...
# 2965                59.30                 7.39      0.000101     0.000000
# 2966                12.50                19.21      0.000098     0.000000
# 2967                45.22                18.89      0.000096     0.000000
# 2968                39.90                16.05      0.000080     0.000000
# 2969                14.50                12.48      0.000023     0.000000
#
#       ...  seller_segment  revenue_at_risk  reputation_risk  negative_rate  \
# 0     ...               2     47412.952832         0.148480       0.584874
# 1     ...               2     28715.403590         0.099485       0.396913
# 2     ...               2     19160.860446         0.063848       0.374784
# 3     ...               2     31846.702311         0.124962       0.399093
# 4     ...               2     28102.915020         0.101472       0.514783
# ...   ...             ...              ...              ...            ...
# 2965  ...               1        66.690000         4.000000       1.000000
# 2966  ...               1        65.140000         4.000000       1.000000
# 2967  ...               1        64.110000         4.000000       1.000000
# 2968  ...               1        55.950000         4.000000       1.000000
# 2969  ...               1        26.980000         4.000000       0.000000
#
#       inv_negative_rate  norm_negative  seller_health_index_v2  \
# 0              0.415126       0.415126                0.742155
# 1              0.603087       0.603087                0.719071
# 2              0.625216       0.625216                0.698122
# 3              0.600907       0.600907                0.721872
# 4              0.485217       0.485217                0.663628
# ...                 ...            ...                     ...
# 2965           0.000000       0.000000                0.000030
# 2966           0.000000       0.000000                0.000029
# 2967           0.000000       0.000000                0.000029
# 2968           0.000000       0.000000                0.000024
# 2969           1.000000       1.000000                0.200007
#
#       sentiment_weighted_risk  late_vs_avg  negative_vs_avg
# 0                27730.600984     0.009767         0.271132
# 1                11397.514104     0.015467         0.083171
# 2                 7181.186039    -0.013633         0.061042
# 3                12709.795027     0.022867         0.085351
# 4                14466.891906     0.007567         0.201040
# ...                       ...          ...              ...
# 2965                66.690000     0.916967         0.686258
# 2966                65.140000     0.916967         0.686258
# 2967                64.110000     0.916967         0.686258
# 2968                55.950000     0.916967         0.686258
# 2969                 0.000000     0.916967        -0.313742
#
# [2970 rows x 24 columns]

# %%
def build_seller_prompt(seller):
    return f"""
    SYSTEM ROLE:
    You're an AI Business Advisor for an E-commerce marketplace.
    
    OBJECTIVE:
    Provide a structured risk assessment.
    
    SELLER METRICS:
    Revenue : {seller.total_revenue}
    Seller Segment : {seller.seller_segment}
    Late Delivery Rate : {seller.late_delivery_rate}
    Platform Avg Late Delivery : {platform_avg['late_delivery_rate']}

    Negative Review Rate : {seller.negative_rate}
    Platform Avg Negative Rate: {platform_avg['negative_rate']}

    Seller Health Index : {seller.seller_health_index_v2}

    INSTRUCTIONS:
    1. Diagnose operational risk.
    2. Compare seller vs platform benchmarks.
    3. Quantify financial exposure.
    4. Provide prioritized improvement roadmap.
    5. Assign risk level : LOW / MEDIUM / HIGH / CRITICAL.

    Respond in stuctured bullet format
    """

# %%
def classify_risk(score):
    if score < 0.2:
        return "CRITICAL"
    elif score < 0.4:
        return "HIGH"
    elif score < 0.6:
        return "MEDIUM"
    else:
        return "LOW"

seller_df['risk_level'] = seller_df['seller_health_index_v2'].apply(classify_risk)

# %%
sample_reviews = df[df['seller_id'] == seller.seller_id]['clean_review'].head(3).tolist()

# %%
# Seller Policy Doc
policy_doc = """
Marketplace Performance Policy:

- Late delivery above 5% increases suspension risk.
- Negative review rate above 20% requires corrective action.
- Revenue concentration in high-risk sellers increases platform exposure.
- Repeat violations trigger seller account audit.
"""

# %%
# Operational playbook
operations_doc = """
Operational Risk Playbook:

Common Causes of High Negative Reviews:
- Poor product quality
- Inaccurate listing
- Damaged shipping
- Poor customer support

Mitigation Strategy:
- QC audits
- Supplier replacement
- Delivery SLA optimization
- Refund policy automation
"""

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
)

documents = [
    Document(page_content = policy_doc),
    Document(page_content = operations_doc)
]

vector_store = FAISS.from_documents(documents, embedding_model)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15292\3022112568.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
retriever = vector_store.as_retriever(search_kwargs={"k":2})

# %%
# RAG-Enhanced Prompt
query = build_seller_prompt(seller)

relevant_docs = retriever.invoke(query)

context = "\n\n".join([doc.page_content for doc in relevant_docs])

final_prompt = f"""
You are AI Risk Business Advisor

Relevant Knowledge Base:
{context}

Speller Analysis Request:
{query}

Use the knowledge base to justify recommendation
"""

# %%
def generate_seller_report(seller, model):
    prompt = build_seller_prompt(seller)
    response = model.generate_content(prompt)
    report_text = response.text
    return report_text

# %%
# Memory Storage Function

def create_memory_document(seller, report_text):
    metadata = {
        "seller_id" : seller.seller_id,
        "segment" : int(seller.seller_segment),
        "health_index" : float(seller.seller_health_index_v2),
        "revenue" : float(seller.total_revenue),
        "timestamp" : str(datetime.datetime.now())
    }
    return Document(
        page_content = report_text,
        metadata = metadata
    )

# %%
def store_report_in_memory(document):
    vector_store.add_documents([document])

# %%
seller = risky_sellers.iloc[0]

report = generate_seller_report(seller, model)

memory_doc = create_memory_document(seller, report)

store_report_in_memory(memory_doc)

print("Report Stored Successfully!")
# Out:
# Report Stored Successfully!

# %%
def retrieve_similar_cases(seller):
    query = f"""
    Seller Segment : {seller.seller_segment}
    Health Index : {seller.seller_health_index_v2}
    Negatuve Index : {seller.negative_rate}
    """
    similar_docs = vector_store.similarity_search(query, k = 3)
    return similar_docs

# %%
similar_cases= retrieve_similar_cases(seller)

historical_context = "\n\n".join([doc.page_content for doc in similar_cases])

final_prompt = f"""
You are an AI Business Risk Advisor. 

Historical Similar Seller Case:
{historical_context}

Now analyze this seller:
{build_seller_prompt(seller)}

Reference historical cases when applicable
"""

# %%
# save
vector_store.save_local("seller_memory_index")

# %%
vector_store = FAISS.load_local("seller_memory_index", embedding_model, allow_dangerous_deserialization=True)

# %%
def calculate_risk_level(seller):

    if seller.negative_rate > 0.5:
        return "HIGH"
    
    if seller.late_delivery_rate > 0.08:
        return "HIGH"
    
    if seller.seller_health_index_v2 < 0.30:
        return "HIGH"
    
    if seller.seller_health_index_v2 < 0.50:
        return "MEDIUM"
    
    return "LOW"

# %%
def process_seller(seller, model):

    risk_level = calculate_risk_level(seller)

    report = generate_seller_report(seller, model)

    print(f"Risk Level: {risk_level}")

    if risk_level == "HIGH":
        memory_doc = create_memory_document(seller, report)
        store_report_in_memory(memory_doc)
        print("HIGH RISK — Report Stored in Memory")
    else:
        print("Not stored (Risk below HIGH threshold)")

    return report

# %%
def create_memory_document(seller, report_text):

    metadata = {
        "seller_id": seller.seller_id,
        "segment": int(seller.seller_segment),
        "health_index": float(seller.seller_health_index_v2),
        "revenue": float(seller.total_revenue),
        "negative_rate": float(seller.negative_rate),
        "late_rate": float(seller.late_delivery_rate),
        "risk_level": calculate_risk_level(seller)
    }

    return Document(
        page_content=report_text,
        metadata=metadata
    )

# %%
def retrieve_high_risk_cases(seller):

    query = f"""
    Segment: {seller.seller_segment}
    Health Index: {seller.seller_health_index_v2}
    Negative Rate: {seller.negative_rate}
    """

    docs = vector_store.similarity_search(query, k=5)

    high_risk_docs = [
        doc for doc in docs
        if doc.metadata.get("risk_level") == "HIGH"
    ]

    return high_risk_docs

# %%
seller_df.to_csv(r"D:\customer-intelligence-engine\data\processed\seller_master.csv" , index = False)

# %%
import joblib
import os

# Create models folder if not exists
models_path = r"D:\customer-intelligence-engine\models"
os.makedirs(models_path, exist_ok=True)

# Save XGBoost model
joblib.dump(xgb, os.path.join(models_path, "xgb_model.pkl"))

print("XGB Model saved successfully!")

# If you really want to save scaler (only if needed)
# joblib.dump(scaler, os.path.join(models_path, "scaler.pkl"))

print("All artifacts saved.")
# Out:
# XGB Model saved successfully!
# All artifacts saved.
